# %%
import sys
import fileinput
import numpy as np
import pandas as pd
data=pd.read_csv('vlist1983-2017-new-03.dat', sep='\s+', header=None)
year=data[0]
sou=data[1]
UT=data[2]
DIS=data[3]
HLA=data[4]
HLO=data[5]
GLA=data[6]
GLO=data[7]
CARR=data[8]
V=data[9]
ERR=data[10]
SCINDEX=data[11]
dtr=np.pi/180.0
rtd=180.0/np.pi
eps1=np.arcsin(0.26)*rtd
eps2=np.arcsin(0.82)*rtd
eps3=np.sin(eps1*dtr)
eps4=np.sin(eps2*dtr)
nyear = []
nsou = []
nUT = []
nDIS = []
nHLA = []
nHLO = []
nGLA = []
nGLO = []
nCARR = []
nV=[]
nERR = []
nSCINDEX = []
#observations between eps range 15-55 deg

n=0
for i in range(0,90438):
    if (SCINDEX[i]!=0.0 and DIS[i] >= eps3 and DIS[i] < eps4):
        nsou.append(sou[i])
        nyear.append(str(year[i]).rjust(6, '0'))
        nUT.append(UT[i])
        nDIS.append(DIS[i])
        nHLA.append(HLA[i])
        nHLO.append(HLO[i])
        nGLA.append(GLA[i])
        nGLO.append(GLO[i])
        nCARR.append(CARR[i])
        nV.append(V[i])
        nERR.append(ERR[i])
        nSCINDEX.append(SCINDEX[i])
        n=n+1
        continue

zip(nyear, nsou,nUT,nDIS,nHLA,nGLA,nGLO,nCARR,nV,nERR,nSCINDEX)
import csv
with open('observations_in_range_15_to_55_deg.txt','w') as f:
    writer=csv.writer(f,delimiter='\t')
    writer.writerows(zip(nyear, nsou, nUT, nDIS, nHLA,nHLO,nGLA,nCARR,nV,nERR,nSCINDEX))
yr = np.zeros(63169)
mon= np.zeros(63169)
day= np.zeros(63169)
fdd= np.zeros(63169)
for i in range(0,n):
    if nDIS[i]== 0.26: nSCINDEX[i]=nSCINDEX[i]/6.008e+02
    if nDIS[i]== 0.27: nSCINDEX[i]=nSCINDEX[i]/6.070e+02
    if nDIS[i]== 0.28: nSCINDEX[i]=nSCINDEX[i]/5.121e+02
    if nDIS[i]== 0.29: nSCINDEX[i]=nSCINDEX[i]/5.564e+02
    if nDIS[i]== 0.30: nSCINDEX[i]=nSCINDEX[i]/7.032e+02
    if nDIS[i]== 0.31: nSCINDEX[i]=nSCINDEX[i]/5.465e+02
    if nDIS[i]== 0.32: nSCINDEX[i]=nSCINDEX[i]/4.143e+02
    if nDIS[i]== 0.33: nSCINDEX[i]=nSCINDEX[i]/4.071e+02
    if nDIS[i]== 0.34: nSCINDEX[i]=nSCINDEX[i]/4.212e+02
    if nDIS[i]== 0.35: nSCINDEX[i]=nSCINDEX[i]/4.435e+02
    if nDIS[i]== 0.36: nSCINDEX[i]=nSCINDEX[i]/3.266e+02
    if nDIS[i]== 0.37: nSCINDEX[i]=nSCINDEX[i]/3.572e+02
    if nDIS[i]== 0.38: nSCINDEX[i]=nSCINDEX[i]/3.531e+02
    if nDIS[i]== 0.39: nSCINDEX[i]=nSCINDEX[i]/2.544e+02
    if nDIS[i]== 0.40: nSCINDEX[i]=nSCINDEX[i]/2.900e+02
    if nDIS[i]== 0.41: nSCINDEX[i]=nSCINDEX[i]/3.223e+02
    if nDIS[i]== 0.42: nSCINDEX[i]=nSCINDEX[i]/2.624e+02
    if nDIS[i]== 0.43: nSCINDEX[i]=nSCINDEX[i]/2.816e+02
    if nDIS[i]== 0.44: nSCINDEX[i]=nSCINDEX[i]/2.866e+02
    if nDIS[i]== 0.45: nSCINDEX[i]=nSCINDEX[i]/2.572e+02
    if nDIS[i]== 0.46: nSCINDEX[i]=nSCINDEX[i]/2.633e+02
    if nDIS[i]== 0.47: nSCINDEX[i]=nSCINDEX[i]/2.059e+02
    if nDIS[i]== 0.48: nSCINDEX[i]=nSCINDEX[i]/1.523e+02
    if nDIS[i]== 0.49: nSCINDEX[i]=nSCINDEX[i]/2.785e+02
    if nDIS[i]== 0.50: nSCINDEX[i]=nSCINDEX[i]/2.276e+02
    if nDIS[i]== 0.51: nSCINDEX[i]=nSCINDEX[i]/1.337e+02
    if nDIS[i]== 0.53: nSCINDEX[i]=nSCINDEX[i]/2.028e+02
    if nDIS[i]== 0.54: nSCINDEX[i]=nSCINDEX[i]/2.024e+02
    if nDIS[i]== 0.55: nSCINDEX[i]=nSCINDEX[i]/1.212e+02
    if nDIS[i]== 0.56: nSCINDEX[i]=nSCINDEX[i]/1.310e+02
    if nDIS[i]== 0.57: nSCINDEX[i]=nSCINDEX[i]/1.010e+02
    if nDIS[i]== 0.58: nSCINDEX[i]=nSCINDEX[i]/2.053e+02
    if nDIS[i]== 0.60: nSCINDEX[i]=nSCINDEX[i]/1.421e+02
    if nDIS[i]== 0.61: nSCINDEX[i]=nSCINDEX[i]/2.077e+02
    if nDIS[i]== 0.62: nSCINDEX[i]=nSCINDEX[i]/7.933e+01
    if nDIS[i]== 0.63: nSCINDEX[i]=nSCINDEX[i]/9.243e+01
    if nDIS[i]== 0.64: nSCINDEX[i]=nSCINDEX[i]/7.303e+01
    if nDIS[i]== 0.65: nSCINDEX[i]=nSCINDEX[i]/7.831e+01
    if nDIS[i]== 0.66: nSCINDEX[i]=nSCINDEX[i]/8.421e+01
    if nDIS[i]== 0.67: nSCINDEX[i]=nSCINDEX[i]/8.523e+01
    if nDIS[i]== 0.68: nSCINDEX[i]=nSCINDEX[i]/1.148e+02
    if nDIS[i]== 0.69: nSCINDEX[i]=nSCINDEX[i]/4.120e+01
    if nDIS[i]== 0.70: nSCINDEX[i]=nSCINDEX[i]/1.263e+02
    if nDIS[i]== 0.71: nSCINDEX[i]=nSCINDEX[i]/8.877e+01
    if nDIS[i]== 0.72: nSCINDEX[i]=nSCINDEX[i]/1.188e+02
    if nDIS[i]== 0.73: nSCINDEX[i]=nSCINDEX[i]/7.520e+01
    if nDIS[i]== 0.74: nSCINDEX[i]=nSCINDEX[i]/9.348e+01
    if nDIS[i]== 0.75: nSCINDEX[i]=nSCINDEX[i]/4.318e+01
    if nDIS[i]== 0.76: nSCINDEX[i]=nSCINDEX[i]/4.215e+01
    if nDIS[i]== 0.77: nSCINDEX[i]=nSCINDEX[i]/6.665e+01
    if nDIS[i]== 0.78: nSCINDEX[i]=nSCINDEX[i]/3.910e+01
    if nDIS[i]== 0.79: nSCINDEX[i]=nSCINDEX[i]/9.810e+01
    if nDIS[i]== 0.80: nSCINDEX[i]=nSCINDEX[i]/5.207e+01
    if nDIS[i]== 0.81: nSCINDEX[i]=nSCINDEX[i]/5.205e+01
    if nDIS[i]== 0.82: nSCINDEX[i]=nSCINDEX[i]/4.300e+01
for i in range(0,n):
    yr[i]=str(nyear[i])[:2]
    mon[i]=str(nyear[i])[2:4]
    day[i]=str(nyear[i])[4:6]
    fdd[i]=float(day[i])+(nUT[i]/24)
fry= np.zeros(63169)
for i in range(0,n):
    if (yr[i]>80):yr[i]=yr[i]+1900
    else:
        yr[i]=yr[i]+2000
for k in range(0,n):
    if (((float(yr[k])%400.0)==0) or (float(yr[k])%100!=0) and (float(yr[k])%4==0)):
        if mon[k]== 1:fry[k]=float(yr[k])+(fdd[k]/366.0)
        if mon[k]== 2:fry[k]=float(yr[k])+((fdd[k]+31)/366.0)
        if mon[k]== 3:fry[k]=float(yr[k])+((fdd[k]+60)/366.0)
        if mon[k]== 4:fry[k]=float(yr[k])+((fdd[k]+91)/366.0)
        if mon[k]== 5:fry[k]=float(yr[k])+((fdd[k]+121)/366.0)
        if mon[k]== 6:fry[k]=float(yr[k])+((fdd[k]+152)/366.0)
        if mon[k]== 7:fry[k]=float(yr[k])+((fdd[k]+182)/366.0)
        if mon[k]== 8:fry[k]=float(yr[k])+((fdd[k]+213)/366.0)
        if mon[k]== 9:fry[k]=float(yr[k])+((fdd[k]+244)/366.0)
        if mon[k]== 10:fry[k]=float(yr[k])+((fdd[k]+274)/366.0)
        if mon[k]== 11:fry[k]=float(yr[k])+((fdd[k]+305)/366.0)
        if mon[k]== 12:fry[k]=float(yr[k])+((fdd[k]+335)/366.0)
    else:
        if mon[k]== 1:fry[k]=float(yr[k])+(fdd[k]/365.0)
        if mon[k]== 2:fry[k]=float(yr[k])+((fdd[k]+31)/365.0)
        if mon[k]== 3:fry[k]=float(yr[k])+((fdd[k]+59)/365.0)
        if mon[k]== 4:fry[k]=float(yr[k])+((fdd[k]+90)/365.0)
        if mon[k]== 5:fry[k]=float(yr[k])+((fdd[k]+120)/365.0)
        if mon[k]== 6:fry[k]=float(yr[k])+((fdd[k]+151)/365.0)
        if mon[k]== 7:fry[k]=float(yr[k])+((fdd[k]+181)/365.0)
        if mon[k]== 8:fry[k]=float(yr[k])+((fdd[k]+212)/365.0)
        if mon[k]== 9:fry[k]=float(yr[k])+((fdd[k]+243)/365.0)
        if mon[k]== 10:fry[k]=float(yr[k])+((fdd[k]+273)/365.0)
        if mon[k]== 11:fry[k]=float(yr[k])+((fdd[k]+304)/365.0)
        if mon[k]== 12:fry[k]=float(yr[k])+((fdd[k]+334)/365.0)
for l in range(0,n):
    fry[l]=round(fry[l], 3)
zip(yr,mon,day,fdd,fry)
import csv
with open('dates_and_fractional_year.txt', 'w') as f:
    
    writer = csv.writer(f, delimiter='\t')
    writer.writerows(zip(yr,mon,day,fdd,fry))
import numpy as np
import sys
import fileinput
f = open('source-27.lis', "r")
f1=f.readlines()
source=[]
for x in f1: 
        x = x.strip('\n')
        source.append(x)
cnt=27        
#Assigning observations for each source into an array
import numpy as np
n_source=cnt
import math
sindx=np.zeros((100000, n_source))
fry2=np.zeros((100000, n_source))
DIS2=np.zeros((100000, n_source))
HLA2=np.zeros((100000, n_source))
HLO2=np.zeros((100000, n_source))
GLA2=np.zeros((100000, n_source))
GLO2=np.zeros((100000, n_source))
CARR2=np.zeros((100000, n_source))
V2=np.zeros((100000, n_source))
ERR2=np.zeros((100000, n_source))
ncnt_arr=np.zeros(n_source)
for i_source in range(0,n_source):
    ncnt=0
    for t in range(0,n-1):
        
        if ((nsou[t] == (source[i_source])) and (nSCINDEX[t]!= 0.0)):
            sindx[ncnt,i_source]=math.log10(10e+04*nSCINDEX[t])
            fry2[ncnt,i_source]=fry[t]
            DIS2[ncnt,i_source]=nDIS[t]
            HLA2[ncnt,i_source]=nHLA[t]
            HLO2[ncnt,i_source]=nHLO[t]
            GLA2[ncnt,i_source]=nGLA[t]
            GLO2[ncnt,i_source]=nGLO[t]
            CARR2[ncnt,i_source]=nCARR[t]
            V2[ncnt,i_source]=nV[t]
            ERR2[ncnt,i_source]=nERR[t]
            ncnt=ncnt+1
    ncnt_arr[i_source]=ncnt
#reduce size of array from 100000 to the maximum needed
sindx=sindx[0:int(max(ncnt_arr)),:]
fry2=fry2[0:int(max(ncnt_arr)),:]
DIS2=DIS2[0:int(max(ncnt_arr)),:]
HLA2=HLA2[0:int(max(ncnt_arr)),:]
HLO2=HLO2[0:int(max(ncnt_arr)),:]
GLA2=GLA2[0:int(max(ncnt_arr)),:]
GLO2=GLO2[0:int(max(ncnt_arr)),:]
CARR2=CARR2[0:int(max(ncnt_arr)),:]
V2=V2[0:int(max(ncnt_arr)),:]
ERR2=ERR2[0:int(max(ncnt_arr)),:]
n_sources=27
#arrays for max mean and rms of scindex computation
simax=np.zeros(n_source)
simean=np.zeros(n_source)
si_sigma=np.zeros(n_source)
#arrays for sigma cutoff
y1=np.zeros(n_source)
y2=np.zeros(n_source)
y3=np.zeros(n_source)
y4=np.zeros(n_source)
#arrays for plot in annual means
data1=np.zeros((33, n_sources))   #array for annual years for each sources
data2=np.zeros((33, n_sources))   #array for anual means for each source
ndata_arr=np.zeros(n_sources) #no of observations for each source
gamma1=45 #lower cutoff for latitude observations
gamma2=90 #higher cutoff for lat observations
gamma3=0 #lowest cutoff for lat observations

# %%
#PLOT CONDITIONS;
import numpy as np
import matplotlib.pyplot as plt
maxpts=100
sindx2 = np.empty((2340,27))
ffry = np.empty((2340,27))
ngla2 = np.empty((2340,27))
ndis2 = np.empty((2340,27))

# sindx2=[[] for _ in range(n_sources)]
# ffry=[[] for _ in range(n_sources)]
# ngla2=[[] for _ in range(n_sources)]
# ndis2=[[] for _ in range(n_sources)]
for i_source in range(0,27):
    if (ncnt_arr[i_source]>maxpts):
        simax[i_source]=max(sindx[0:int(ncnt_arr[i_source]),i_source])
        npts=ncnt_arr[i_source]
        for i in range (0, int(npts)):
            sindx[i, i_source]=sindx[i, i_source]/float(simax[i_source])#normalise with max value
        sindx2[0:int(npts),i_source]=sindx[0:int(npts),i_source]
        ffry[0:int(npts),i_source]=fry2[0:int(npts),i_source]
        ngla2[0:int(npts),i_source]=GLA2[0:int(npts),i_source]
        ndis2[0:int(npts),i_source]=DIS2[0:int(npts),i_source]
        simean[i_source]=np.mean(sindx2[0:int(npts),i_source])
        si_sigma[i_source]=math.sqrt(np.var(sindx2[0:int(npts),i_source]))
# # #new arrays for fry and sindx by dropping all points above 2 sigma            
        y1[i_source]=(simean[i_source]+((si_sigma[i_source])*2.0))
        y2[i_source]=(simean[i_source]-((si_sigma[i_source])*2.0))
        y3[i_source]=0.65*(simean[i_source]+((si_sigma[i_source])*2.0))
        y4[i_source]=(simean[i_source]-((si_sigma[i_source])*2.0))
        newarr=np.zeros((4,int(npts)))
        ss=0
        for i in range(0,int(npts)-1):
            if ((ffry[i,i_source])<=2018.0 and (ffry[i,i_source])>1970.0):
                
                if (((sindx2[i,i_source])>y2[i_source]) and (sindx2[i, i_source] <= y1[i_source])):
                    newarr[0,ss]=ffry[i,i_source] #fractional year
                    newarr[1,ss]=sindx2[i,i_source] #normalized sc-index
                    newarr[2,ss]=ngla2[i,i_source] #heliographic latitude
                    newarr[3,ss]=ndis2[i,i_source] #distance from the sun
                    ss=ss+1    
                    
                elif(((sindx2[i, i_source])>y4[i_source]) and (sindx2[i,i_source]<=y3[i_source])):
                    newarr[0,ss]=ffry[i,i_source] #fractional year
                    newarr[1,ss]=sindx2[i,i_source] #normalized sc-index
                    newarr[2,ss]=ngla2[i,i_source] #heliographic latitude
                    newarr[3,ss]=ndis2[i,i_source] #distance from the sun
                    ss=ss+1
       # print(ss)            
        xx=np.zeros(ss)
        yy=np.zeros(ss)
        xxl=np.zeros(ss)
        xxd=np.zeros(ss)
        xx=newarr[0,0:ss-1]
        yy=newarr[1,0:ss-1]
        #print(xx)        
        fig=plt.figure()
        ax=fig.add_subplot(111)
        xxl=newarr[2,0:ss-1]
        xxd=newarr[3,0:ss-1]
        ymax=max(yy)
        ymin=min(yy)
        xmax=max(xx)
        xmin=min(xx)
        dy=(ymax-ymin)/10
#Grouping observations for high lat sources
        if (max(abs(xxl)))>45:
            xx2=np.zeros(ss)
            yy2=np.zeros(ss)
            xxl2=np.zeros(ss)
            xxd2=np.zeros(ss)
            ss2=0
            for i in range(0,ss-1):
                if (abs(xxl[i])>= gamma1 and abs(xxl[i])<gamma2):
                    xx2[ss2]=xx[i]
                    yy2[ss2]=yy[i]
                    xxl2[ss2]=xxl[i]
                    xxd2[ss2]=xxd[i]
                    ss2=ss2+1
            xx2=xx2[0:ss2-1]
            yy2=yy2[0:ss2-1]
            plt.scatter(xx,yy,c='darkgray', marker='+', label='plot year and scindex')
            plt.scatter(xx2,yy2, c='r', marker='.', label='high latitude obs')
            xxl2=xxl2[0:ss2-1]
            xxd2=xxd2[0:ss2-1]
            xxn2=np.zeros(10000)
            yyn2=np.zeros(10000)
            jj2=0
            for j2 in range(1983,2017+1,1):
                ny=j2
                sumx2=0.0
                sumy2=0.0
                ncount2=0.0  #no of points per year
                
                for i in range(0,ss2-1):
                    if (int(xx2[i]) == ny):
                        sumx2=sumx2+xx2[i]
                        sumy2=sumy2+yy2[i]
                        ncount2=ncount2+1
                if (ncount2!=0):
                    xxn2[jj2]=sumx2/float(ncount2)
                    yyn2[jj2]=sumy2/float(ncount2)
                    jj2=jj2+1
            xxn2=xxn2[0:jj2-1]
            yyn2=yyn2[0:jj2-1]
            highl=(ss2*100)/float(ss)
            highl=int(highl)
            
# #Low latidude
            xx3=np.zeros(ss)
            yy3=np.zeros(ss)
            xxl3=np.zeros(ss)
            xxd3=np.zeros(ss)
            ss3=0
            
            for i in range(0, ss-1):
                if(abs(xxl[i]) >= gamma3 and abs(xxl[i])<gamma1):
                    xx3[ss3]=xx[i]
                    yy3[ss3]=yy[i]
                    xxl3[ss3]=xxl[i]
                    xxd3[ss3]=xxd[i]
                    ss3=ss3+1
            xx3=xx3[0:ss3-1]
            yy3=yy3[0:ss3-1]
            xxl3=xxl3[0:ss3-1]
            xxd3=xxd3[0:ss3-1]
            plt.scatter(xx3,yy3, c='darkgray', marker='+', label='low lat observations')
            xxn3=np.zeros(10000)
            yyn3=np.zeros(10000)
            jj3=0
            for j3 in range(1983, 2017+1,1):
                ny=j3
                sumx3=0.0
                sumy3=0.0
                ncount3=0
                for i in range(0,ss3-1):
                    if (int(xx3[i])==ny):
                        sumx3=sumx3+xx3[i]
                        sumy3=sumy3+yy3[i]
                        ncount3=ncount3+1
                if (ncount3 != 0):
                    xxn3[jj3]=sumx3/float(ncount3)
                    yyn3[jj3]=sumy3/float(ncount3)
                    jj3=jj3+1
            xxn3=xxn3[0:jj3-1]
            yyn3=yyn3[0:jj3-1]
            plt.scatter(xxn3,yyn3, facecolors='none', edgecolors='b', marker='o', label='annual means for low latitude')
# #   PLOT DATA
            data1[0:jj3-1,i_source]=xxn3[0:jj3-1]
            data2[0:jj3-1,i_source]=yyn3[0:jj3-1]
            ndata_arr[i_source]=jj3
    
        else:
            xxn=np.zeros(10000)
            yyn=np.zeros(10000)
            jj=0
            for j in range(1983,2017+1,1):
                ny=j
                sumx=0.0
                sumy=0.0
                ncount=0
                for i in range(0,ss-1):
                    if (int(xx[i]) == ny):
                        sumx=sumx+xx[i]
                        sumy=sumy+yy[i]
                        ncount=ncount+1
                if (ncount != 0):
                    xxn[jj]=sumx/float(ncount)
                    yyn[jj]=sumy/float(ncount)
                    jj=jj+1
            
            xxn=xxn[0:jj-1]
            yyn=yyn[0:jj-1]
            data1[0:jj-1,i_source]=xxn[0:jj-1]
            data2[0:jj-1,i_source]=yyn[0:jj-1]
            ndata_arr[i_source]=jj
            plt.scatter(xx,yy,c='darkgray', marker='+', label='plot year and scindex')
            plt.scatter(xxn,yyn,s=80, facecolors='none', edgecolors='b', marker='o', label='4')
plt.xlim(1982,2021)            
ax.text(1985.0, 0.55, '2347-026', fontsize=15)
ax.text(2009, 0.70, '0.26 ≤ r ≤ 0.82 AU')            
plt.savefig('27',dpi=1080, transparent=False, bbox_inches='tight', facecolor='w', edgecolor='w')
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:57: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
a=[]
for i in range(0,18):
    a.append(data1[i,0])
for i in range(0,22):
    a.append(data1[i,1])
for i in range(0,18):
    a.append(data1[i,2])
for i in range(0,30):
    a.append(data1[i,3])
for i in range(0,26):
    a.append(data1[i,4])
for i in range(0,25):
    a.append(data1[i,5])
for i in range(0,31):
    a.append(data1[i,6])
for i in range(0,32):
    a.append(data1[i,7])
for i in range(0,32):
    a.append(data1[i,8])
for i in range(0,32):
    a.append(data1[i,9])
for i in range(0,26):
    a.append(data1[i,10])
for i in range(0,28):
    a.append(data1[i,11])
for i in range(0,28):
    a.append(data1[i,12])
for i in range(0,31):
    a.append(data1[i,13])
for i in range(0,27):
    a.append(data1[i,14])
for i in range(0,24):
    a.append(data1[i,15])
for i in range(0,21):
    a.append(data1[i,16])
for i in range(0,32):
    a.append(data1[i,17])
for i in range(0,27):
    a.append(data1[i,18])
for i in range(0,30):
    a.append(data1[i,19])
for i in range(0,25):
    a.append(data1[i,20])
for i in range(0,30):
    a.append(data1[i,21])
for i in range(0,19):
    a.append(data1[i,22])
for i in range(0,23):
    a.append(data1[i,23])
for i in range(0,22):
    a.append(data1[i,24])
for i in range(0,17):
    a.append(data1[i,25])
for i in range(0,18):
    a.append(data1[i,26])
b=[]
for i in range(0,18):
    b.append(data2[i,0])
for i in range(0,22):
    b.append(data2[i,1])
for i in range(0,18):
    b.append(data2[i,2])
for i in range(0,30):
    b.append(data2[i,3])
for i in range(0,26):
    b.append(data2[i,4])
for i in range(0,25):
    b.append(data2[i,5])
for i in range(0,31):
    b.append(data2[i,6])
for i in range(0,32):
    b.append(data2[i,7])
for i in range(0,32):
    b.append(data2[i,8])
for i in range(0,32):
    b.append(data2[i,9])
for i in range(0,26):
    b.append(data2[i,10])
for i in range(0,28):
    b.append(data2[i,11])
for i in range(0,28):
    b.append(data2[i,12])
for i in range(0,31):
    b.append(data2[i,13])
for i in range(0,27):
    b.append(data2[i,14])
for i in range(0,24):
    b.append(data2[i,15])
for i in range(0,21):
    b.append(data2[i,16])
for i in range(0,32):
    b.append(data2[i,17])
for i in range(0,27):
    b.append(data2[i,18])
for i in range(0,30):
    b.append(data2[i,19])
for i in range(0,25):
    b.append(data2[i,20])
for i in range(0,30):
    b.append(data2[i,21])
for i in range(0,19):
    b.append(data2[i,22])
for i in range(0,23):
    b.append(data2[i,23])
for i in range(0,22):
    b.append(data2[i,24])
for i in range(0,17):
    b.append(data2[i,25])
for i in range(0,18):
    b.append(data2[i,26])
zip(a,b)
import csv
with open('annual_means', 'w') as f:
    
    writer = csv.writer(f, delimiter='\t')
    writer.writerows(zip(a,b))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
x, y = pd.Series(a, name="Years"), pd.Series(b,name='m')
ax=sns.regplot(x=a, y=b, marker=".",label="Annual means")
plt.title('Temporal variation of Scintillation index')
plt.xlim(1982,2020)
ax.text(1985, 0.45, 'Total no. of sources = 27')
plt.xlabel('Years')
plt.ylabel('m')
plt.legend()

plt.savefig('Scindexvstimeinyears',dpi=1080, transparent=False, bbox_inches='tight', facecolor='w', edgecolor='w')
