# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv('annualmeans-scindex.txt', sep ='\s+', header=None)
x=data[0]
y=data[1]
import pandas as pd
x, y = pd.Series(x, name="Years of observations"), pd.Series(y, name="Scintillation Index")
ax = sns.regplot(x=x, y=y, marker="o")
plt.title('Temproal variation of Scintillation Index')
plt.savefig('Scindexvstimeinyears',dpi=720,transparent=False,bbox_inches='tight',facecolor='w', edgecolor='w')
